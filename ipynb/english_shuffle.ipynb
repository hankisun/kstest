# %%
import re
s = "### come / go"
m = re.match(r"^#+ ([\w\W]+)", s)
print(m)
# Out:
# <re.Match object; span=(0, 13), match='### come / go'>

# %%
import re
s = "  ###   come / go"
m = re.match(r"^ *#+\s*(.+)", s)
print(m)
m.groups()
# Out:
# <re.Match object; span=(1, 18), match='  ###   come / go'>
# ('come / go',)

# %%
def check_doc_title(l):
    if m := re.match(r" *#+\s*(.+)", l):
        return m.groups()
    return None

for t in check_doc_title(s):
    print(t)
# Out:
# come / go

# %%
m.groups()
# Out:
# ('come / go',)

# %%
# ss = "   | Something came up.                            | 문제가 생겼어              |"
ss = "|||"
# mm = re.finditer(r"\|([^\|]+)", ss)

# for m in mm:
#     print(m.groups())


mm = re.findall(r"\|([^\|]+)", ss)
print(mm)
# Out:
# []

# %%
ss = "|svd|dfdr|"
m = re.search(r"^\|", ss)
m
# Out:
# <re.Match object; span=(0, 1), match='|'>

# %%
mm.
# Out:
# '| Something came up.                            | 문제가 생겼어              |'

# %%
ss = "   | Something came up.                            | 문제가 생겼어              |"
mm = re.search(r"\|([^\|]+)\|([^\|]+)\|", ss)
print(mm)
mm.groups()
# Out:
# <re.Match object; span=(3, 75), match='| Something came up.                            |>
# (' Something came up.                            ', ' 문제가 생겼어              ')

# %%
mm.groups()
# Out:
# (' Something came up.                            ', ' 문제가 생겼어              ')

# %%
dash = "| --------------------------------------------- | -------------------- | -- |"
d = re.match(r"^ *\|(?:\s*\:?-+\:?\s*\|)+", dash)
print(d)
print(d.span()[1])
print(len(dash))
# Out:
# <re.Match object; span=(0, 81), match='    | ------------------------------------------->
# 81
# 81

# %%
d.span()
# Out:
# (0, 7)

# %%
d.group()
# Out:
# '| --------------------------------------------- | -------------------- |'

# %%
t = ['a','b']
dd = {t[0]: 1, t[1]: 2}
dd

a = '   bbb   '
a.strip()
# Out:
# 'bbb'

# %%
def walas():
    return 1

if w:=walas() or w == 2:
    print('in')
    print(w)
# Out:
# in
# 1

# %%
from pydantic import BaseModel
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 from pydantic import BaseModel
#
# ModuleNotFoundError: No module named 'pydantic'

# %%
from loguru import logger
import re
import sys

logger.remove()
logger.add(sys.stdout, format="{level} {message}", level="DEBUG")

def new_tab_dict(title=""):
    return {
        "title": title,
        "columns": [],
        "contents": [],
        "before_sep_bar": True
    }

def check_doc_title(l):
    if m := re.search(r"^#+\s*(.+)", l):
        return m.groups()[0]
    return None

def parse_table_row(l):
    if m := re.findall(r"\|([^\|]+)", l):
        return m
    return None

def check_table_column(l, tab_dict):
    if tab_dict["before_sep_bar"] is False:
        return None
    return parse_table_row(l)  

def is_seperation_bar(l):
    if m := re.search(r"^\|(?:\s*\:?-+\:?\s*\|)+", l):
        logger.debug(f"{m.span()} {len(l)}")
        if m.span()[1] == len(l):
            return True
    return False

def is_md_table(l):
    if m := re.search(r"^\|", l):
        return True
    return False

def insert_to_tab_dict(l, tab_dict):
    if is_seperation_bar(l):
        tab_dict["before_sep_bar"] = False
    elif columns := check_table_column(l, tab_dict):
        logger.debug(columns)
        tab_dict['columns'] = [column.strip() for column in columns]
    else: # contents
        parsed = parse_table_row(l)
        tab_dict['contents'].append({column: content.strip() for (column, content) in zip(tab_dict['columns'], parsed)})

docs = []
tab_dict = new_tab_dict()

with open('spic.md') as f:
    while True:
        l = f.readline()
        if not l:
            break
        l = l.strip()
        if title := check_doc_title(l):
            if tab_dict["contents"]:
                docs.append(tab_dict)
            tab_dict = new_tab_dict(title)
        elif is_md_table(l):
            insert_to_tab_dict(l, tab_dict)

import json
logger.info(json.dumps(docs, ensure_ascii=False, indent=2))
# Out:
# DEBUG [' Eng                                           ', ' Kor                  ']
# DEBUG (0, 72) 72
# DEBUG [' Eng                                    ', ' Kor                 ']
# DEBUG (0, 64) 64
# DEBUG [' Eng                                                     ', ' Kor                             ']
# DEBUG (0, 93) 93
# DEBUG [' Eng                              ', ' Kor                 ']
# DEBUG (0, 58) 58
# DEBUG [' Eng                                       ', ' Kor                      ']
# DEBUG (0, 72) 72
# DEBUG [' Eng                               ', ' Kor               ']
# DEBUG (0, 57) 57
# DEBUG [' Eng                                                  ', ' Kor                         ']
# DEBUG (0, 86) 86
# DEBUG [' Eng                             ', ' Kor                    ']
# DEBUG (0, 60) 60
# DEBUG [' Eng                                 ', ' Kor             ']
# DEBUG (0, 57) 57
# DEBUG [' Eng                                        ', ' Kor                                ']
# DEBUG (0, 83) 83
# DEBUG [' Eng                                                   ', ' Kor                 ']
# DEBUG (0, 79) 79
# DEBUG [' Eng                                                           ', ' Kor                       ']
# DEBUG (0, 93) 93
# DEBUG [' Eng                                              ', ' Kor                 ']
# DEBUG (0, 74) 74
# DEBUG [' Eng                                            ', ' Kor                    ']
# DEBUG (0, 75) 75
# DEBUG [' Eng                                 ', ' Kor                  ']
# DEBUG (0, 62) 62
# DEBUG [' Eng                                             ', ' Kor                     ']
# DEBUG (0, 77) 77
# DEBUG [' Eng                                                  ', ' Kor                    ']
# DEBUG (0, 81) 81
# INFO [
#   {
#     "title": "come / go",
#     "columns": [
#       "Eng",
#       "Kor"
#     ],
#     "contents": [
#       {
#         "Eng": "Something came up.",
#         "Kor": "문제가 생겼어"
#       },
#       {
#         "Eng": "Milk went bad.",
#         "Kor": "우유가 상했어"
#       },
#       {
#         "Eng": "Spring has come",
#         "Kor": "봄이 왔어"
#       },
#       {
#         "Eng": "Did she come to the party?",
#         "Kor": "그 애 파티에 왔니?"
#       },
#       {
#         "Eng": "I wish I could come with you guys",
#         "Kor": "너희들과 놀러가면 좋을텐데"
#       },
#       {
#         "Eng": "After a long talk we came to an understanding",
#         "Kor": "한참 얘기한 끝에야 의견이 일치됐어요"
#       },
#       {
#         "Eng": "My eye sight is going",
#         "Kor": "시력이 나빠지고 있어요"
#       },
#       {
#         "Eng": "My eye sight is coming back",
#         "Kor": "시력이 좋아지고 있어"
#       }
#     ],
#     "before_sep_bar": false
#   },
#   {
#     "title": "bring & take",
#     "columns": [
#       "Eng",
#       "Kor"
#     ],
#     "contents": [
#       {
#         "Eng": "What brought you here?",
#         "Kor": "무슨 일로 오셨어요?"
#       },
#       {
#         "Eng": "Spring brings new beginnings",
#         "Kor": "봄이 새로운 시작을 가져와요"
#       },
#       {
#         "Eng": "I'll take you a good place around here",
#         "Kor": "내가 오늘 맛집으로 데려가줄께"
#       },
#       {
#         "Eng": "Bring some beer",
#         "Kor": "올 때 맥주좀 가져와"
#       },
#       {
#         "Eng": "I'll bring my car at 6",
#         "Kor": "내가 6시에 차갖고 네 쪽으로 갈께"
#       }
#     ],
#     "before_sep_bar": false
#   },
#   {
#     "title": "work - 작동하고 기능하는 이미지",
#     "columns": [
#       "Eng",
#       "Kor"
#     ],
#     "contents": [
#       {
#         "Eng": "My phone isn't working",
#         "Kor": "폰이 작동 안해"
#       },
#       {
#         "Eng": "I think that works for me",
#         "Kor": "그 때 시간 돼"
#       },
#       {
#         "Eng": "We are working on a new project",
#         "Kor": "우리 새 프로젝트에 매달려있어"
#       },
#       {
#         "Eng": "When you're applying for a job age can work against you",
#         "Kor": "취직하는데 나이가 불리할 수 있어"
#       },
#       {
#         "Eng": "I work out every Monday to stay fit",
#         "Kor": "나는 건강한 몸매를 유지하기 위해 매주 월욜마다 운동해요"
#       },
#       {
#         "Eng": "It didn't work out",
#         "Kor": "해결이 안됐어"
#       }
#     ],
#     "before_sep_bar": false
#   },
#   {
#     "title": "make - 노력 움직임을 더해 결과 만들어 내는 것",
#     "columns": [
#       "Eng",
#       "Kor"
#     ],
#     "contents": [
#       {
#         "Eng": "That makes sense",
#         "Kor": "그거 말 된다"
#       },
#       {
#         "Eng": "Hey don't make a fuss",
#         "Kor": "호들갑 좀 떨지마"
#       },
#       {
#         "Eng": "Do I make myself clear?",
#         "Kor": "제 말 이해 되셨나요?"
#       },
#       {
#         "Eng": "I hope you'll be able to make it",
#         "Kor": "네가 꼭 와줬으면 좋겠어"
#       },
#       {
#         "Eng": "I was made to do a lot of work",
#         "Kor": "(원치않은)많은 일들을 해야 했어요"
#       }
#     ],
#     "before_sep_bar": false
#   },
#   {
#     "title": "turn - 변화를 동반한 움직임",
#     "columns": [
#       "Eng",
#       "Kor"
#     ],
#     "contents": [
#       {
#         "Eng": "I'm turning 30 next year. How time flies.",
#         "Kor": "내가 내년이면 30살이에요. 시간 참 빨라요"
#       },
#       {
#         "Eng": "His face turns red whenever he drinks",
#         "Kor": "그는 술만 마시면 얼굴이 빨개져요"
#       },
#       {
#         "Eng": "Milk has turned sour.",
#         "Kor": "우유가 상했어요"
#       },
#       {
#         "Eng": "This book is a real page turner",
#         "Kor": "이 책 정말 잘 읽혀요"
#       }
#     ],
#     "before_sep_bar": false
#   },
#   {
#     "title": "keep 변함없이 유지하다",
#     "columns": [
#       "Eng",
#       "Kor"
#     ],
#     "contents": [
#       {
#         "Eng": "You should keep the promise",
#         "Kor": "약속 지켜야해"
#       },
#       {
#         "Eng": "I'm sorry to keep you waiting.",
#         "Kor": "기다리게 해서 미안해"
#       },
#       {
#         "Eng": "You should keep it a secret",
#         "Kor": "비밀 지켜야해"
#       },
#       {
#         "Eng": "Keep up the good word",
#         "Kor": "잘하고 있어 계속 수고해"
#       },
#       {
#         "Eng": "Keep it up",
#         "Kor": ""
#       },
#       {
#         "Eng": "Could you keep an eye on my back?",
#         "Kor": "제 가방 좀 봐주실 수 있나요?"
#       }
#     ],
#     "before_sep_bar": false
#   },
#   {
#     "title": "break 깨뜨리고 부수는 이미지",
#     "columns": [
#       "Eng",
#       "Kor"
#     ],
#     "contents": [
#       {
#         "Eng": "He broke the silence",
#         "Kor": "침묵을 깨고 입을 열었다"
#       },
#       {
#         "Eng": "He broke the ice by telling a joke",
#         "Kor": "그는 농담으로 서먹한 분위기를 깼다"
#       },
#       {
#         "Eng": "We broke up a week ago",
#         "Kor": "우리 일주일 전에 헤어졌어요"
#       },
#       {
#         "Eng": "I don't know how I am going to break the news to him",
#         "Kor": "안좋은 소식이 있는데 어떻게 전해야 할지 모르겠어"
#       },
#       {
#         "Eng": "My face is breaking out",
#         "Kor": "피부가 뒤집어졌어"
#       }
#     ],
#     "before_sep_bar": false
#   },
#   {
#     "title": "hold 대상을 꽉 잡아서 움직이지 못하게 함",
#     "columns": [
#       "Eng",
#       "Kor"
#     ],
#     "contents": [
#       {
#         "Eng": "Hold me tight",
#         "Kor": "꽉 안아줘"
#       },
#       {
#         "Eng": "This place can hold 3000 people",
#         "Kor": "이곳은 사람을 3000명 수용할 수 있어"
#       },
#       {
#         "Eng": "I don't hold a grudge",
#         "Kor": "나 뒤끝 없어"
#       },
#       {
#         "Eng": "Hold the onions please",
#         "Kor": "양파 넣지 말아주세요"
#       },
#       {
#         "Eng": "Hold the mayo please",
#         "Kor": "마요네즈 빼주세요"
#       },
#       {
#         "Eng": "Hold that thought",
#         "Kor": "잠깐 기다려봐"
#       }
#     ],
#     "before_sep_bar": false
#   },
#   {
#     "title": "put on / wear",
#     "columns": [
#       "Eng",
#       "Kor"
#     ],
#     "contents": [
#       {
#         "Eng": "She's wearing a cardigan",
#         "Kor": "그녀는 가디건을 입고 있어요"
#       },
#       {
#         "Eng": "I'm not wearing any makeup",
#         "Kor": "난 화장을 안한 상태야"
#       },
#       {
#         "Eng": "She's putting on a dress",
#         "Kor": "그녀는 드레스를 입는 중이야"
#       },
#       {
#         "Eng": "You should take off your shoes here",
#         "Kor": "여기선 신발을 벗어야해"
#       },
#       {
#         "Eng": "Can I try this on?",
#         "Kor": "입어봐도 될까요?"
#       }
#     ],
#     "before_sep_bar": false
#   },
#   {
#     "title": "suspect / doubt",
#     "columns": [
#       "Eng",
#       "Kor"
#     ],
#     "contents": [
#       {
#         "Eng": "My mother suspects that I'm seeing someone",
#         "Kor": "누군가를 사귀는 중이라고 의심해요"
#       },
#       {
#         "Eng": "I doubt that you're telling the truth",
#         "Kor": "네 말이 사실인지 의심스러워 네가 사실을 말하지 않는 것 같아"
#       },
#       {
#         "Eng": "I suspect that he is lying to me",
#         "Kor": "그가 나한테 거짓말 하는 거 같아"
#       },
#       {
#         "Eng": "I doubt that he is lying to me",
#         "Kor": "그가 나한테 거짓말 하는지 아닌지 모르겠는데 아닌거 같아"
#       },
#       {
#         "Eng": "I doubt that they will be back together",
#         "Kor": "걔네 다시  안사귈 거 같아"
#       },
#       {
#         "Eng": "There's no doubt about it",
#         "Kor": "의심할 여지가 없지"
#       }
#     ],
#     "before_sep_bar": false
#   },
#   {
#     "title": "hurt / injure",
#     "columns": [
#       "Eng",
#       "Kor"
#     ],
#     "contents": [
#       {
#         "Eng": "You hurt my feelings",
#         "Kor": "네가 내 기분을 상하게했어"
#       },
#       {
#         "Eng": "She was injured in a car crash",
#         "Kor": "차사고로 다쳤어"
#       },
#       {
#         "Eng": "I hurt my legs and it hurts a lot",
#         "Kor": "다리를 다쳤어"
#       },
#       {
#         "Eng": "I broke up with him and it really hurts me",
#         "Kor": "그와 헤어져서 마음이 넘 아파"
#       },
#       {
#         "Eng": "I got my finger stuck in the doors and it hurts a lot",
#         "Kor": "문틈에 손이 껴서 넘 아파요"
#       },
#       {
#         "Eng": "He was not able to play due to his ankle injury",
#         "Kor": "발목부상으로 경기에 나가지 못했어요"
#       }
#     ],
#     "before_sep_bar": false
#   },
#   {
#     "title": "interrupt / interfere",
#     "columns": [
#       "Eng",
#       "Kor"
#     ],
#     "contents": [
#       {
#         "Eng": "You interrupted our conversation",
#         "Kor": "대화에 끼어들지 마"
#       },
#       {
#         "Eng": "I try not to interfere with other people's affairs",
#         "Kor": "다른사람의 일에 간섭하려고 하지 않아요"
#       },
#       {
#         "Eng": "I want you to stop interfering and I will take care of it",
#         "Kor": "간섭 좀 그만해 내 일은 내가 알아서 할께"
#       },
#       {
#         "Eng": "I'm trying to tell you something important Don't interrupt me",
#         "Kor": "너한테 할 중요한 얘기가 있어 말 끊지 말아줘"
#       },
#       {
#         "Eng": "Stop bothering me",
#         "Kor": "귀찮게 하지 마"
#       },
#       {
#         "Eng": "It's a bother",
#         "Kor": "그거 너무 귀찮아"
#       }
#     ],
#     "before_sep_bar": false
#   },
#   {
#     "title": "expect / look forward to",
#     "columns": [
#       "Eng",
#       "Kor"
#     ],
#     "contents": [
#       {
#         "Eng": "I am expecting a baby in March",
#         "Kor": "3월에 출산 예정이에요"
#       },
#       {
#         "Eng": "I am looking forward to meeting you this weekend",
#         "Kor": "이번주 너 만나는 거 너무 기대돼!"
#       },
#       {
#         "Eng": "I can't wait to see you this weekend",
#         "Kor": ""
#       },
#       {
#         "Eng": "He's been looking forward to being a father",
#         "Kor": "그는 항상 아빠가 되고 싶어 했어"
#       },
#       {
#         "Eng": "I didn't expect you to come today",
#         "Kor": "네가 오늘 올 거라 생각 못했어"
#       }
#     ],
#     "before_sep_bar": false
#   },
#   {
#     "title": "break / rest",
#     "columns": [
#       "Eng",
#       "Kor"
#     ],
#     "contents": [
#       {
#         "Eng": "Let's take a coffee break",
#         "Kor": "커피 마시면서 잠깐 쉬자"
#       },
#       {
#         "Eng": "You should go get some rest",
#         "Kor": "이제 좀 푹 쉬어"
#       },
#       {
#         "Eng": "I'm going to work out during my lunch break",
#         "Kor": "점심시간에 잠깐 운동하러 갈게요"
#       },
#       {
#         "Eng": "You worked so hard all day long. Get some rest",
#         "Kor": "오늘 종일 열심히 일했어. 이제 좀 쉬어"
#       }
#     ],
#     "before_sep_bar": false
#   },
#   {
#     "title": "guess / suppose",
#     "columns": [
#       "Eng",
#       "Kor"
#     ],
#     "contents": [
#       {
#         "Eng": "I guess he is on his way",
#         "Kor": "지금쯤 오고 있을 것 같은데"
#       },
#       {
#         "Eng": "I suppose she is busy at the moment",
#         "Kor": "그녀는 오늘도 바쁠 것 같은데"
#       },
#       {
#         "Eng": "I guess she knows my phone number",
#         "Kor": "그녀가 내 번호를 갖고 있을 것 같아"
#       },
#       {
#         "Eng": "She is supposed to come by 2",
#         "Kor": "그녀가 2시까지 오기로 되어 있는데"
#       },
#       {
#         "Eng": "You are not supposed to be here",
#         "Kor": "너 여기 있으면 안되잖아"
#       }
#     ],
#     "before_sep_bar": false
#   },
#   {
#     "title": "believe / trust",
#     "columns": [
#       "Eng",
#       "Kor"
#     ],
#     "contents": [
#       {
#         "Eng": "I trust her completely",
#         "Kor": "난 그녀를 완전히 신뢰해"
#       },
#       {
#         "Eng": "I believe you",
#         "Kor": "네 말이 사실일 거라고 믿어"
#       },
#       {
#         "Eng": "I trust you",
#         "Kor": "나는 너를 신뢰해"
#       },
#       {
#         "Eng": "I can't believe that you've been cheating on me",
#         "Kor": "네가 계속 바람을 피웠다니 믿을 수가 없다"
#       },
#       {
#         "Eng": "I trust that he won't cheat on me",
#         "Kor": "그는 날 두고 바람을 피우지 않을 거야"
#       },
#       {
#         "Eng": "I believe in God",
#         "Kor": "나는 신의 존재를 믿어"
#       },
#       {
#         "Eng": "I don't believe in ghosts",
#         "Kor": "난 귀신의 존재를 믿지 않아"
#       }
#     ],
#     "before_sep_bar": false
#   }
# ]

# %%
def write_in_english_loop(contents):
    correct = 0
    incorrect = 0
    cnt = len(contents)
    for i, idx in enumerate(random.sample(range(0, cnt), k=cnt)):
        print(f"[{i+1:3}/{cnt+1:3}] Please write in English")
        print()
        print(">>> " + contents[idx]["Kor"])
        print(">>> ", end="")
        answer = input("press Q to quit")
        if answer.upper() == 'Q':
            print("quit")
            break
        print(answer)
        print()
        if answer == contents[idx]["Eng"]:
            print("    Correct! Greate!!")
            correct += 1
        else:
            print("    Incorrect..")
            incorrect += 1
            print(">>> " + contents[idx]["Eng"])
        print()
        print(f"=== (Correct {correct:3} / Incorrect {incorrect:3}) ===")
        print()
    return (correct, incorrect)

while True:
    print("=== English Writing Test ===")
    print("1. Test ALL")
    print("2. Select a Table")
    print()
    print("Select a number (Q to quit) : ")
    print()
    selection = input("Enter selection: ")

    if selection.upper() == "Q":
        print("quit")
        break
    
    if selection == '1':
        print("[Test ALL]")
        contents = [content for tab in docs for content in tab["contents"]]
        write_in_english_loop(contents)
    elif selection == '2':
        back_flag = False
        while True:
            print("[Select a Table]")
            tab_list = [tab["title"] for tab in docs]
            for i, title in enumerate(tab_list):
                print(f"{i+1}. {title}")
            print()
            print("Select a table number (Q to go back) : ")
            selection = input("Enter table number: ")
            if selection.upper() == "Q":
                back_flag = True
                break
            try:
                selection = int(selection)
            except ValueError as e:
                print("Only Number is accepted. try again..")
                continue
            selection -= 1
            if selection >= 0 and selection < len(tab_list):
                break
            else:
                print("Invalid number. Try again...")
        
        if back_flag:
            print("go back")
            continue
        else:
            contents = docs[selection]["contents"]
            write_in_english_loop(contents)
# Out:
# === English Writing Test ===
# 1. Test ALL
# 2. Select a Table
#
# Select a number (Q to quit) :
#
# [Select a Table]
# 1. come / go
# 2. bring & take
# 3. work - 작동하고 기능하는 이미지
# 4. make - 노력 움직임을 더해 결과 만들어 내는 것
# 5. turn - 변화를 동반한 움직임
# 6. keep 변함없이 유지하다
# 7. break 깨뜨리고 부수는 이미지
# 8. hold 대상을 꽉 잡아서 움직이지 못하게 함
# 9. put on / wear
# 10. suspect / doubt
# 11. hurt / injure
# 12. interrupt / interfere
# 13. expect / look forward to
# 14. break / rest
# 15. guess / suppose
# 16. believe / trust
#
# Select a table number (Q to go back) :
# [  1/  8] Please write in English
#
# >>> 나는 너를 신뢰해
# >>> I trust you
#
#     Correct! Greate!!
#
# === (Correct   1 / Incorrect   0) ===
#
# [  2/  8] Please write in English
#
# >>> 나는 신의 존재를 믿어
# >>> I believe in
#
#     Incorrect..
# >>> I believe in God
#
# === (Correct   1 / Incorrect   1) ===
#
# [  3/  8] Please write in English
#
# >>> 그는 날 두고 바람을 피우지 않을 거야
# >>> I believe he will not blow me up
#
#     Incorrect..
# >>> I trust that he won't cheat on me
#
# === (Correct   1 / Incorrect   2) ===
#
# [  4/  8] Please write in English
#
# >>> 난 그녀를 완전히 신뢰해
# >>> I completely believe in her
#
#     Incorrect..
# >>> I trust her completely
#
# === (Correct   1 / Incorrect   3) ===
#
# [  5/  8] Please write in English
#
# >>> 네 말이 사실일 거라고 믿어
# >>> I believe in you
#
#     Incorrect..
# >>> I believe you
#
# === (Correct   1 / Incorrect   4) ===
#
# [  6/  8] Please write in English
#
# >>> 네가 계속 바람을 피웠다니 믿을 수가 없다
# >>> I can't believe you've cheated on me
#
#     Incorrect..
# >>> I can't believe that you've been cheating on me
#
# === (Correct   1 / Incorrect   5) ===
#
# [  7/  8] Please write in English
#
# >>> 난 귀신의 존재를 믿지 않아
# >>> I don't believe ghost
#
#     Incorrect..
# >>> I don't believe in ghosts
#
# === (Correct   1 / Incorrect   6) ===
#
# === English Writing Test ===
# 1. Test ALL
# 2. Select a Table
#
# Select a number (Q to quit) :
#
# quit

# %%
import random

random.sample(range(0,10), k=10)
# Out:
# [1, 3, 0, 9, 5, 4, 7, 6, 2, 8]

# %%
cnt = 2
print(f"[{cnt:10}]")
# Out:
# [         2]
