# %%
class Coordinate:
    def __init__(self, lat: float, long:float) -> None:
        # self._latitude = self._longitude = None
        self._latitude = lat
        self._longitude = long

    @property
    def latitude(self) -> float:
        return self._latitude
    
    @latitude.setter
    def latitude(self, lat_value: float) -> None:
        if lat_value not in range(-90, 90 + 1):
            raise ValueError(f'Invalid latitude: {lat_value}')
        self._latitude = lat_value

    @property
    def longitude(self) -> float:
        return self._longitude
    
    @longitude.setter
    def longitude(self, long_value: float) -> None:
        if long_value not in range(-180, 180 + 1):
            raise ValueError(f'Invalid longitude: {long_value}')
        self._longitude = long_value

# %%
cor = Coordinate(38, 190)
cor.latitude, cor.longitude
# Out:
# (38, 190)

# %%
cor.longitude = 200
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Untitled-1.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W2sdW50aXRsZWQ%3D?line=0'>1</a> cor.longitude = 200
#
# Untitled-1.ipynb Cell 3 line 2
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W2sdW50aXRsZWQ%3D?line=20'>21</a> @longitude.setter
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W2sdW50aXRsZWQ%3D?line=21'>22</a> def longitude(self, long_value: float) -> None:
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W2sdW50aXRsZWQ%3D?line=22'>23</a>     if long_value not in range(-180, 180 + 1):
# ---> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W2sdW50aXRsZWQ%3D?line=23'>24</a>         raise ValueError(f'Invalid longitude: {long_value}')
# ...

# %%
cor.__dict__
# Out:
# {'_latitude': 38, '_longitude': 180}

# %%
class A:
    def __init__(self):
        self.l = []
    
    def get_l(self):
        return self.l
    
    def set_l(self, s:str):
        self.l.append(s)
    
a1 = A()
a2 = A()

a1.set_l('h')
a2.get_l()
# Out:
# []

# %%
a1.get_l()
# Out:
# ['h']

# %%
['h']*5
# Out:
# ['h', 'h', 'h', 'h', 'h']

# %%
[None]*5
# Out:
# [None, None, None, None, None]

# %%
class B:
    var1 = 0

    def __init__(self, v):
        self.var2 = v

b1 = B('b1')
b2 = B('b2')

b1.var1, b2.var1
# Out:
# (0, 0)

# %%
b1.var2, b2.var2
# Out:
# ('b1', 'b2')

# %%
b1.var1 = 4

# %%
b2.var1
# Out:
# 0

# %%
b1.var1
# Out:
# 4

# %%
b1.__dict__
# Out:
# {'var2': 'b1', 'var1': 4}

# %%
b2.__dict__
# Out:
# {'var2': 'b2'}

# %%
B.var1
# Out:
# 0

# %%
target = [0, 2, 3, 4, 5, None, 7, 8, 9, 10]
result = filter(None, target)
print(list(result))
# Out:
# [2, 3, 4, 5, 7, 8, 9, 10]

# %%
None == None
# Out:
# True
